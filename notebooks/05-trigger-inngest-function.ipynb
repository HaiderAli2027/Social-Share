# %%
import setup
setup.init()

# %%
import inngest
from Scheduler.client import inngest_client

# %%
await inngest_client.send(
    inngest.Event(
        name="app/my_function",
        data={"abc": 123}
    )
)
# Out:
# ['01KPBHMH4D7AGNN94RRZCJNB00']

# %%
inngest_client.send_sync(
    inngest.Event(
        name="app/my_function",
        data={"abc": "checking 134"}
    )
)
# Out:
# ['01KPBHMJ70KMM2S8J0YVS42E9G']
