# %%
import setup
setup.init()

# %%
print("Hello WOrld")
# Out:
# Hello WOrld

# %%
from django.contrib.auth import get_user_model

# %%
User = get_user_model()

# %%
haiderLinkedIn_User = User.objects.get(username="haiderali")
haiderLinkedIn_User.email
# Out:
# 'haider@gmail.com'
