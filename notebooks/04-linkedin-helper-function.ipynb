# %%
import setup
setup.init()

# %%
from django.contrib.auth import get_user_model

# %%
User = get_user_model()

# %%
haiderLinkedIn_User = User.objects.get(username="haiderali")
text = "This is working so well, have you seen it?"

# %% [raw]
# import helper

# %%
from helper import linkedin

# %%
linkedin.post_to_linkedin(haiderLinkedIn_User, text)
# Out:
# --------------------------------------------------------------------
# DoesNotExist                       Traceback (most recent call last)
# File ~\Documents\NationalTextileUniversity\Web development\Django-project\Social Share\src\helper\linkedin.py:13, in get_linkedin_user_details(user)
#      12 try:
# ---> 13     linkedin_social = user.socialaccount_set.get(provider='linkedin')
#      14 except:
#
# File ~\Documents\NationalTextileUniversity\Web development\Django-project\Social Share\venv\Lib\site-packages\django\db\models\manager.py:87, in BaseManager._get_queryset_methods.<locals>.create_method.<locals>.manager_method(self, *args, **kwargs)
#      85 @wraps(method)
#      86 def manager_method(self, *args, **kwargs):
# ---> 87     return getattr(self.get_queryset(), name)(*args, **kwargs)
#
# File ~\Documents\NationalTextileUniversity\Web development\Django-project\Social Share\venv\Lib\site-packages\django\db\models\query.py:639, in QuerySet.get(self, *args, **kwargs)
# ...
